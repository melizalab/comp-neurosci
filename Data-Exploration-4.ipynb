# %% [markdown]
# ## Data Exploration 4: Preliminary Figure
#
# This notebook provides a template for the 4th stage in your Data Exploration assignment. Now that you have laid out your proposal, you need to demonstrate a concrete step towards your specific aim.
#
# Submit your work as an ipynb file to Canvas. Only one submission per group. Write the names of all group members below.

# %% [markdown]
# ### Describe your project
#
# In the cell below, briefly describe (1) the overall goal of the project and (2) what you specifically want to accomplish. Incorporate any feedback you may have received on the proposal.

# %% [markdown]
# ### Outline your approach
#
# In the next cell, make a step-by-step outline of your approach to what you want to accomplish. For example:
#
# 1. For each unit in L2a, compute the spectrotemporal receptive field.
#     1. Read the sound waveform stimulus files into 1D arrays.
#     2. Read the spike response times for the unit into lists of arrays
#     3. Average and bin the trials to estimate the firing rate.
#     4. Compute the STRF from 75% of the data using linear regression
#     5. Test the STRF on the remaining 25% of the data. Discard the cell if the performance (correlation coefficient) is less than 0.25.
# 2. Cluster the neurons by how similar their receptive fields are
#     1. ...

# %% [markdown]
# ### Preliminary analysis
#
# Execute enough of your proposed approach to generate a preliminary proof of principle figure. For example, you might load in the data from one neuron, compute an STRF, and plot it. If you aren't able to get all the way there, make sure you stop with a figure that demonstrates what you've accomplished and then briefly document what challenge you need to address next.
#
# Make sure that your code is runnable. Document any additional packages you had to install and why.
